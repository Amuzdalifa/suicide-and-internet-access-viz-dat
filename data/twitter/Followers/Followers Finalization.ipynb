# %%
import json
import tweepy

# %%
# Authentication tokens from your Twitter API
# (Censored here because they are private)
CONSUMER_KEY = "Q3BuOCb6YpCcjxRLX80si7iaY"
CONSUMER_SECRET = "8LmPPMK1j40QKn3jKzNP7MSGQXL90ZXfbHLtRbRR6d1mZKVQwe"
ACCESS_TOKEN = "462603440-1WpphlO6HmRcVDZJjglIosJekSOmLLSQ2rkAC3b9"
ACCESS_TOKEN_SECRET = "4A2vZ2ioqwHJANDAHZTPFoKp9scbN9zTAnhlXbkLboZdZ"

# Oauth
auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)

api = tweepy.API(auth, wait_on_rate_limit = True, wait_on_rate_limit_notify = True, retry_count = 3, retry_delay = 60)

# %%
with open("323041793.json", 'r') as f:
    datastore = json.load(f)
datastore
# Out:
# {'screen_name': 'afifdhiaamru',
#  'user_id': 323041793,
#  'num_followers': 419,
#  'followers_ids': ['BreSindy',
#   'sekali__',
#   'W4D35u',
#   'Aniqahmhp2',
#   'DangerDhani',
#   'MeysiListiya',
#   'Wakanda66928363',
#   'danifalone',
#   'kugyxlangit',
#   'javascript03',
#   'putriataka',
#   'Syalalaranika',
#   'NurRahm88291295',
#   'gilangramadhvn',
#   'haloichasf',
#   'vinepinn',
#   'salbxrn',
#   'fharlup',
#   'adhiniii',
#   'rexorenscounty',
#   'hamidahrtg',
#   'fariatny',
#   'vaniiitoon',
#   'Petronelaa',
#   'hafisreal',
#   'yubenik123',
#   'fahricsnh',
#   'pe_nyimak',
#   'RatnaMahendra3',
#   'put_mil',
#   'lilly_l1ll',
#   'dheamadhan1',
#   'isabelabrenda10',
#   'valzoniii',
#   'NhieClouds0928',
#   'liatkamu',
#   'endraaaaaaaaa',
#   'trickymindful',
#   'yinavlinzia',
#   'The_Warman',
#   'dhefinaamalia',
#   'Annisalsabila64',
#   'sprite_boyz',
#   'Riska_oktavias',
#   'RFAsriani',
#   'udakkkkk',
#   'Sapabaelah2',
#   'ilhamPAT',
#   'billydhanoktavn',
#   'IDOLspy',
#   'quinniehrley',
#   'stockypedro',
#   'deliyaRP',
#   'FzDilla',
#   'kamubgsd',
#   'hanzdef',
#   'cahyana129',
#   'priskaaiueo',
#   'Damayanti_03',
#   'Bacucicaya',
#   'IrmaDRMN',
#   'fitri1102',
#   'prasenjaa',
#   'fandy_sykes',
#   'Satriatjandra1',
#   'Melki_horas',
#   '_ryannayrs',
#   'Bibeh1000',
#   'alizlovescherry',
#   'bennysiauw89',
#   'aesthypster',
#   'bib_bibbbb',
#   'SenopatiPutri',
#   'Reiza6690',
#   'jasminmillen',
#   'Acilravandamm1',
#   'Taufiq_Attaufiq',
#   'aknavoj',
#   'radis_sudjono',
#   'arbihamam_',
#   'madinbest',
#   'mbagaspraditya',
#   'NovelliaDEP',
#   'ratihanjar2',
#   'nisacadasss',
#   'qdrnnd2',
#   'zhrazr',
#   'mput_alqodir',
#   'PUPUTsangJUARA',
#   'iamgorengku',
#   'azkanurf',
#   'iqbalsetyaaji1',
#   'Taetaevottom',
#   'dedekuanlinku',
#   'yp40032223',
#   'Azzahra58559842',
#   'sabilaRA_',
#   'finaacil',
#   'yeyee____',
#   'SlaveFav',
#   'bteomgyu',
#   'sepiiiiaaaa',
#   'luv_tees',
#   'ayundariska',
#   'sovirakhasanah',
#   'caylekersey_',
#   'PandhuSeptian',
#   'tidudabin',
#   'annastsy_far',
#   'herieric18',
#   'pretania73',
#   'ivanaratana121',
#   'haifainayah',
#   'Santo_Rias',
#   'tatadesitaaa',
#   'Pluviopphiles',
#   'namasayaann',
#   'grayishblue__',
#   'KevinSebast_',
#   'adoremings',
#   'Bulanstyngrhn_',
#   'flowsroses',
#   'hendroapriadi',
#   'delxonsangadji',
#   'yaelahberjanda',
#   'Tasya62266009',
#   'Radit1401',
#   'aulyaad_',
#   'ranuuy',
#   'savagedaladalla',
#   'Dio02071178',
#   'rsahani001',
#   'komuluna',
#   'rossyaldo',
#   '_missescape',
#   'Rezaaryani_',
#   'hehw_',
#   'jellcii',
#   'nurfais_',
#   'masbedil',
#   'nomaddust',
#   'Fatimah98796539',
#   'dorkagetkaget',
#   'permanabs4279',
#   'Noemphaty32',
#   'FardaSadiyah',
#   'fajyar',
#   'achmad_thobroni',
#   'carameloleche',
#   'Reinanggita',
#   'ikochans',
#   'iyanoksip',
#   'Rayaaap',
#   'caffeineadxx',
#   'RizalAb88332828',
#   'adindaspm_',
#   'pernahdioprasi',
#   'Kyoo36591241',
#   'sarerote',
#   'tjank_gha',
#   'anaknyamamipapi',
#   'inikennoy',
#   'RajaDwiy',
#   'mimiperrr',
#   'Anifahnaswan2',
#   'dandiirzani',
#   'kdpm_',
#   '329d6112',
#   'putiptr',
#   'ncentinao',
#   'midzxyz',
#   'whatthehellSSG',
#   'firdaniadm',
#   'elshaaaz',
#   'intanrm',
#   'aminatuzzahra25',
#   'yuliakrtika',
#   'SantriPop',
#   'ekasulistiawati',
#   'handiwaeee',
#   'tyachandra2',
#   'oakenshitsss',
#   'Dllaptr',
#   'indriadne',
#   'edmenfrain',
#   'Ziva09136756',
#   'ayscrl',
#   'indartopratama1',
#   'dittapratiwii12',
#   'khanschas',
#   'brrunchbabe',
#   'HannaJehan',
#   'rosiherleen',
#   'kartika_praja',
#   'NaufalHilmi_',
#   'AdityaWahyuSa13',
#   'muhammad_anaa',
#   'Auliamutiara01',
#   'dierhaa666',
#   'salsxx1',
#   'dickakeenan',
#   'therpshaen',
#   'Xbbyw',
#   'kunyitdapur',
#   'livinmoon',
#   'ilovecloudandyu',
#   'sofia0701001',
#   'jasminearma',
#   'Jajangwakcuy',
#   'icachayy',
#   'mymelzz',
#   'mahlukdarimars',
#   'liebedickk',
#   'Teresaniken',
#   'Fjrianika',
#   'hilwaisanartist',
#   '_justNINIK_',
#   'afifah_luvi135',
#   'yahyat3',
#   'kuasbuluk',
#   'PanggilSajaHan',
#   'chcrrylips',
#   'airydaniar',
#   'Ronnamaraya',
#   'BajakDibajak',
#   'Femyliafah',
#   'AldoSalmon3',
#   'dndryni',
#   'ttop95',
#   'valatmorghulis',
#   'bry_yyyy',
#   'nindytahapsari',
#   'celinedyo',
#   'richrichard89',
#   'christy_desmita',
#   'itsrainyhere_',
#   'itsmeboiii_',
#   'momingds37',
#   'aritajessicas',
#   'Devidew',
#   'enthusiastyou',
#   'blxckcattt',
#   'tebakduludong',
#   '_officialkelly',
#   'vyrrs',
#   'FebianiNurul',
#   'KokooDwii',
#   'CATNEES',
#   'bananamilkycow',
#   'shaaily01',
#   'widyodongo',
#   'imtad119',
#   'jichangminwife',
#   'yahau8',
#   'Grclpnku',
#   'shellywoyla',
#   'facsinated',
#   'siriplele',
#   'annamerrl',
#   'yhnfjr_',
#   'primachyy',
#   'Mellann5',
#   'tishatishu',
#   'windyfuza1',
#   'prof_fakta',
#   'pewds_x_joji',
#   'sendychya',
#   'reka_annisaa',
#   'verikaamalia',
#   'CSerpong',
#   'Vidixz_Yikwa',
#   'alicemorikanon',
#   'izah1102',
#   'vidixz10',
#   'itadakimay',
#   'ridhorama9',
#   'albanahasan91',
#   '1Dionez',
#   'septakurniawa14',
#   'anisanurkholi13',
#   'ria_iryani',
#   'MRI_AFAA',
#   'firdausocta1',
#   'wifi_idTAN',
#   'irfanmahendra_',
#   'donifirmansya2',
#   'deamarella_',
#   'nandaviolita',
#   'Ayu_Xiaoling',
#   'Fateqah_AS',
#   'YukoFajarH',
#   'saharanora1',
#   'nurkhialrdputri',
#   'sifaudin_08',
#   'Bunga_tiara2601',
#   'whywidodo',
#   'Sendyptr',
#   'canadian46',
#   'Fara_SH48',
#   'vava_SH48',
#   'shasanadia1',
#   'auliahanunn',
#   'Ny_widya',
#   'AnandaMartha03',
#   'farrel_ivan',
#   'ay_amalia1',
#   'ArinaTakeda',
#   'DerryDeathCore',
#   'adelamonov',
#   'vanya_vaniaa',
#   'shipcrack716',
#   'Hazel1675',
#   'andarasilvia',
#   'marvienstal',
#   'TianoDewa_3',
#   'VenessaAboudi',
#   'sscbandung',
#   'DonahoJune',
#   'BasiliaLossett',
#   'S_Gen3JKT48',
#   'AliottaMarcene',
#   'ConourCarlee',
#   'Caffeophile',
#   'iqbalanas_29',
#   'Tayviaa',
#   'TheBeatGalaxy',
#   'adeloveshanju',
#   'aryawiratama10',
#   'HaritsD',
#   'renaldi_adji',
#   'nadiyahangelica',
#   'Denaauliaaa',
#   'rodeoshop6',
#   'EkaMantri',
#   'ladyfranch534',
#   'dheday_vyita',
#   'jogja_computer',
#   '__minasartika',
#   'dndacesr_',
#   'bapakustadz',
#   'andryantondi',
#   'ElvaAnna',
#   'delaneraretha',
#   'UdangBakar_',
#   'praskila_dicky',
#   'KidMiddi',
#   'david43089430',
#   'Brunzh',
#   'dhiraj1810',
#   'DwiSarrie',
#   'FariqFariqparjo',
#   'alankzoldyck',
#   'mahendr03133427',
#   'SacrikBand',
#   'arirezapahlevi',
#   'ArthurDa5895',
#   'addinfaqih_',
#   'anonymousTM_48',
#   'shidiq_aero11',
#   'fauziAM_',
#   'Nicodhemus_2411',
#   'Salsa_zsazsa',
#   'ziadmarwan92',
#   'riky_melodic',
#   'farah_nisrina30',
#   'poetra_batasa03',
#   'FajarPardomuan',
#   'Cut_Mega28',
#   'Sindy_Wang',
#   'rahmad_baladewa',
#   'onosasmitajaya',
#   'fariqparjo',
#   'Herdin_Alamsyah',
#   'novichsnh',
#   'ananda_silviana',
#   'AlfianVockets',
#   'calvin_panji',
#   'Nia_niyul01',
#   'Altalarik12',
#   'Rizky_ramdan',
#   'Dillaa4Dillaa',
#   'Wulansalwa1',
#   'muchtar_86',
#   'ChristianNisme',
#   'mubashir1233',
#   'freefollowing_3',
#   'Wackyclarence',
#   '_whitejuly',
#   'LilVatoHomez',
#   'goosong_newbie',
#   'DdeRastafarauye',
#   'alddhyID',
#   'PribadiSidik_',
#   'mohliskanah',
#   'Boyarie2525',
#   'intannurfadill1',
#   'WendyNaryody',
#   'IslamicIrock',
#   'SimonRonnals',
#   'anitaagultom',
#   'kukuhsmodparker',
#   'ranooot',
#   'ade481',
#   'Chorizhao',
#   'LolaGitya',
#   'victor_vladimir',
#   'AnissaMaharan99',
#   'w_hernita',
#   'Nurhalimah0402',
#   'C1_10112UN',
#   'rian_arrohman',
#   'Fateqah',
#   'MardianaNC',
#   'riancjahgataan',
#   'nisaltv',
#   'amriansyahpi',
#   'naimaaaa2',
#   'yogyagrosir',
#   'zakaters'],
#  'following_ids': [265428468,
#   41541261,
#   1162835678,
#   2358610496,
#   1073802955474710529,
#   2294366113,
#   622750881,
#   890252352,
#   2795562217,
#   608886358,
#   1073388082320138241,
#   1634551123,
#   2487833544,
#   336369416,
#   3035721379,
#   839163848342945792,
#   1070264911031201793,
#   67543581,
#   2564594732,
#   33818937,
#   612493849,
#   36905540,
#   95369720,
#   2225367584,
#   107947965,
#   44136556,
#   333438574,
#   94805910,
#   1431598688,
#   100753435,
#   373993938,
#   64135759,
#   178690996,
#   2579706949,
#   710838951989346304,
#   3196354567,
#   57606211,
#   1406936455,
#   250651014,
#   1224919658,
#   479567736,
#   469896939,
#   2348133950,
#   3096217956,
#   116128653,
#   736497077627166720,
#   3071562996,
#   351444182,
#   819663729348354048,
#   1469404700,
#   372193629,
#   1217590255,
#   3196284414,
#   801616986,
#   1229230646,
#   76647722,
#   2927943246,
#   286647042,
#   813185917,
#   69353163,
#   754564182,
#   926787912,
#   2908492554,
#   408592788,
#   68577507,
#   2908001989,
#   71436318,
#   634569839,
#   280853501,
#   29742478,
#   1003403497,
#   903172238,
#   554131497,
#   73102464,
#   978808357,
#   413101419,
#   80323736,
#   129659873,
#   179034014,
#   2495762364,
#   89375749,
#   2397452317,
#   2397627511,
#   47596019,
#   366987179,
#   2393249293,
#   1346715949,
#   23343960,
#   1929942954,
#   1372530528,
#   104556071,
#   341987176,
#   568731749,
#   137282671,
#   28491581,
#   106024816,
#   69183155,
#   1214348478,
#   52664274,
#   33182692,
#   2341752037,
#   857793314,
#   481303897,
#   347881310,
#   159797500,
#   102856089,
#   296605257,
#   440907789,
#   1263641155,
#   41633698,
#   442383693,
#   886416570,
#   69876693,
#   32358893,
#   382735002,
#   1109182627,
#   1489797462,
#   139407855,
#   1243831333,
#   285361431,
#   21726758,
#   312416470,
#   279461542,
#   432689276,
#   432677590]}

# %%
following_unames = []
for uid in datastore['following_ids']:
    uname = api.get_user(uid).screen_name
    print(uname)
    following_unames.append(uname)
following_unames
# Out:
# facsinated
# difasabila
# reka_annisa
# aelvarita
# verrenchristyy
# annamerrl
# siriplele
# nadhiaelsa
# nindytahapsari
# yhnfjr_
# Mellann5
# primachyy
# wilmana_i
# hipstermaid
# gmarthagraciela
# apiipp
# windyfuza1
# Eno_Bening
# bismilahpasrah
# pergijauh
# ramengvrl
# vngnc
# _mardial_
# FaktaAgama
# Lqrqs
# andori
# efkahfajar
# addiems
# hati2diInternet
# alfiahainun
# Saniajosefina
# celineayu
# richbrian
# sushitrash
# 88rising
# Eve_JKT48
# tishatishu
# PutriBachtiarr
# hayatinisaputri
# har_harly
# Teresaniken
# _nadisyara
# hilwaisanartist
# reka_annisaa
# mxfida
# zaraJKT48
# officialumntv
# UMNRADIO
# verikaamalia
# vanesavanillaaa
# Deviina_
# itadakimay
# Fidly_JKT48
# renaJKT48
# AffhDini
# TMCPoldaMetro
# Fateqah_AS
# Wina_WISH
# firda_salsa
# OmDennis
# LayariaNetwork
# CroozJKT
# milenia_tintin
# nurkhialrdputri
# jakpost
# Sendyptr
# KompasTV
# _widikidiw_
# Vierratale
# chelseaislan
# uniqloindonesia
# Pak_JK
# adilaysrn
# Iradiojakarta
# netmediatama
# adelamonov
# ridwankamil
# MartinusTito
# theGOODSdept
# racheltjhia
# HIPratama
# S_SiscaJKT48
# C_MichelleJKT48
# liputan6dotcom
# jokowi
# Caffeophile
# TeamBebyKSK
# kompascom
# ABSTeamBeby
# nadiyahangelica
# PT_TransJakarta
# CommuterLine
# Denaauliaaa
# detikhot
# Crooz
# SchitzoApparel
# detikcom
# Manhattanjkt
# ozradiobandung
# OZRadioJakarta
# Cindygulla0
# jpopzilla
# BebyOshi
# ElvaAnna
# delaneraretha
# aryopeppers
# LawsonIndonesia
# Nayopaya
# AnkoruMagz
# JSNaviDonna
# imajineshon
# Della_JKT48
# JapaneseStation
# HaiMagazine
# giansingit
# RoadkillPic
# AlfianVockets
# HIPradana
# Ngaidol_Jekeiti
# Rizky_ramdan
# bukugpu
# Vespa_IND
# Aelke_mariska
# RENAN0ZAWA
# bebyJKT48
# ['facsinated',
#  'difasabila',
#  'reka_annisa',
#  'aelvarita',
#  'verrenchristyy',
#  'annamerrl',
#  'siriplele',
#  'nadhiaelsa',
#  'nindytahapsari',
#  'yhnfjr_',
#  'Mellann5',
#  'primachyy',
#  'wilmana_i',
#  'hipstermaid',
#  'gmarthagraciela',
#  'apiipp',
#  'windyfuza1',
#  'Eno_Bening',
#  'bismilahpasrah',
#  'pergijauh',
#  'ramengvrl',
#  'vngnc',
#  '_mardial_',
#  'FaktaAgama',
#  'Lqrqs',
#  'andori',
#  'efkahfajar',
#  'addiems',
#  'hati2diInternet',
#  'alfiahainun',
#  'Saniajosefina',
#  'celineayu',
#  'richbrian',
#  'sushitrash',
#  '88rising',
#  'Eve_JKT48',
#  'tishatishu',
#  'PutriBachtiarr',
#  'hayatinisaputri',
#  'har_harly',
#  'Teresaniken',
#  '_nadisyara',
#  'hilwaisanartist',
#  'reka_annisaa',
#  'mxfida',
#  'zaraJKT48',
#  'officialumntv',
#  'UMNRADIO',
#  'verikaamalia',
#  'vanesavanillaaa',
#  'Deviina_',
#  'itadakimay',
#  'Fidly_JKT48',
#  'renaJKT48',
#  'AffhDini',
#  'TMCPoldaMetro',
#  'Fateqah_AS',
#  'Wina_WISH',
#  'firda_salsa',
#  'OmDennis',
#  'LayariaNetwork',
#  'CroozJKT',
#  'milenia_tintin',
#  'nurkhialrdputri',
#  'jakpost',
#  'Sendyptr',
#  'KompasTV',
#  '_widikidiw_',
#  'Vierratale',
#  'chelseaislan',
#  'uniqloindonesia',
#  'Pak_JK',
#  'adilaysrn',
#  'Iradiojakarta',
#  'netmediatama',
#  'adelamonov',
#  'ridwankamil',
#  'MartinusTito',
#  'theGOODSdept',
#  'racheltjhia',
#  'HIPratama',
#  'S_SiscaJKT48',
#  'C_MichelleJKT48',
#  'liputan6dotcom',
#  'jokowi',
#  'Caffeophile',
#  'TeamBebyKSK',
#  'kompascom',
#  'ABSTeamBeby',
#  'nadiyahangelica',
#  'PT_TransJakarta',
#  'CommuterLine',
#  'Denaauliaaa',
#  'detikhot',
#  'Crooz',
#  'SchitzoApparel',
#  'detikcom',
#  'Manhattanjkt',
#  'ozradiobandung',
#  'OZRadioJakarta',
#  'Cindygulla0',
#  'jpopzilla',
#  'BebyOshi',
#  'ElvaAnna',
#  'delaneraretha',
#  'aryopeppers',
#  'LawsonIndonesia',
#  'Nayopaya',
#  'AnkoruMagz',
#  'JSNaviDonna',
#  'imajineshon',
#  'Della_JKT48',
#  'JapaneseStation',
#  'HaiMagazine',
#  'giansingit',
#  'RoadkillPic',
#  'AlfianVockets',
#  'HIPradana',
#  'Ngaidol_Jekeiti',
#  'Rizky_ramdan',
#  'bukugpu',
#  'Vespa_IND',
#  'Aelke_mariska',
#  'RENAN0ZAWA',
#  'bebyJKT48']

# %%
datastore['following_ids'] = following_unames

# %%
with open('data.json', 'w') as outfile:
    json.dump(datastore, outfile)
